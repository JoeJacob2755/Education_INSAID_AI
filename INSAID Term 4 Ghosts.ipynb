# %% [markdown]
# ## ------------TERM 4 PROJECT: CLASIFICATION OF GHOSTS, GOBLINS & GHOULS-----------
# ### ------------------------------------------ (Use of Advanced ML Algorithms)----------------------------------------------
#                                                  BY
#                                               Jojo Jacob
#                                             Cohort: Nov 2020

# %% [markdown]
# ### Table of Contents
# - 1. [Introduction](#section1)<br>
#     - 1.1 [Data Set Description](#section11)<br>
#     - 1.2 [About Project](#section12)<br>
# - 2. [Problem Statement](#section2)<br>
# - 3. [Project Approch](#section3)<br>
# - 4. [Importing Libraries and Packages](#section4)<br>
# - 5. [Creating Custom Functions](#section5)<br>
# - 6. [Data Preprocessing](#section6)<br>
#     - 6.1[Data Loading](#section61)<br>
#     - 6.2[Data Preperation](#section62)<br>
#     - 6.3[Observations: Data Preperation](#section63)<br>
# - 7. [Data Processing](#section7)<br>
#     - 7.1 [Basic Preprocessing](#section71)<br>
#     - 7.2 [Process Individual Columns](#section72)<br>
#         - 7.2.1 [Bone Length](#section721)<br>
#         - 7.2.2 [Rotting Flesh](#section722)<br>
#         - 7.2.3 [Hair Length](#section723)<br>
#         - 7.2.4 [Has Soul](#section724)<br>
#         - 7.2.5 [Color](#section725)<br>
#         - 7.2.6 [Type](#section725)<br>
#     - 7.3 [Obsevations](#section73)<br>
# - 8. [EDA](#section8)<br>
#    - 8.1 [Distibution of Count of Type of Creatures](#section81)<br>
#    - 8.2 [Comparison of Features of each Type using Histplot](#section82)<br>
#    - 8.3 [Anomaly Detection in Features](#section83)<br>
#        - 8.3.1 [Checking for Anomalies in Features using Boxplots](#section831)<br>
#        - 8.3.2 [Checking for Anomalies in Features within Species using Boxplots](#section832)<br>
#    - 8.4 [Checking for Corelation between Features within Species using Pair & Scatter Plots](#section84)<br>
#        - 8.4.1 [Checking for Corelation between Features within using Pair Plots](#section841)<br>
#        - 8.4.2 [Checking Corelation between Features: Reg Plots](#section842)<br>
#        - 8.4.3 [Checking Corelation between Features within Species: LM Plots](#section843)<br>
#    - 8.5 [Understanding  Features](#section85)<br>
#        - 8.5.1 [Measuring Features across Species: Swarm Plot](#section851)<br>
#        - 8.5.2 [Measuring Features within Species: Violin Plot](#section852)<br>
#    - 8.6 [Understanding Data uing Andrews Plot](#section86)<br>
#
# - 9. [Modelling](#section9)<br>
#     - 9.1 [Preparing the Test Data](#section9.1)<br>
#     - 9.2 [Feature Selection](#section9.2)<br>
#     - 9.3 [Scaling of Data](#section9.3)<br>
#     - 9.4 [Modelling Using Supervised Approches](#section9.4)<br>
#         - 9.4.1 [Initializing Models](#section941)<br>
#         - 9.4.2 [Predicting Using Models](#section942)<br>
#     - 9.5 [Unsupervised Approches](#section95)<br>
#         - 9.5.1 [K Means Clustering](#section952)<br>
#     - 9.6 [Model Evaluation](#section96)<br>
# - 10. [Test Data Classification](#section100)<br>
#      - 10.1 [Exploring and Processing Test data](#section101)<br>
#      - 10.2 [Prediction on Test Data using Selected Model: Bagging Classifier](#section102)<br>
#      - 10.2 [Creating and Saving Final Result](#section103)<br>
# - 11. [Conclusion](#section12)<br>
#     - 11.1 [Summary](#section111)<br>
#     - 11.2 [Limitations of Project](#section112)<br>
#     - 11.3 [Lessons Learned](#section113)<br>
# - 12. [Acknowldgement](#section12)<br>

# %% [markdown]
# ## 1. Intoduction<a class="anchor" id="section1"></a>

# %% [markdown]
# ### 1.1 Data Set Description<a class="anchor" id="section11"></a>
#
# - Data set consist of description of three types of mythical creatures, __Ghosts__, __Goblins__ and __Ghouls__.
# - Two seprate data sets, one each for train and test are provided.
#     - Train data set has the type of creature mentioned.
#     - Test data set does not contain the type of creature.
# - These creatures are characterised by distinct features:
#     - __Bone Length__
#     - __Hair Length__
#     - __Flesh Condition__
#     - __Having or Not Having Soul__
#     - __Color__
# - Aim is to categorise the creatures based on the features and build a model that can predict the category.

# %% [markdown]
# ### 1.2 About Project<a class="anchor" id="section12"></a>
# - This project is done as part of Machine Learning Term 4 Assesment at __INSAID__.
# - The project envisage to showcase the understanding about Data Analysis, Advanced Machine Learning Algorithms, Anomaly Detection, Optimisation of ML Algorithms covered up to Term 4.

# %% [markdown]
# ## 2. Problem Statement<a class="anchor" id="section2"></a>
#
# - The data set contains 3 classes of mythical creatures.
#
# - Task is to __Predicted the type of the creature__, These are
#     - __Ghosts__
#     - __Goblins__
#     - __Ghouls__
#
# - Variables on which the prediction is to be made isas below
#     - __Bone Length__
#     - __Hair Length__
#     - __Flesh Condition__
#     - __Having or Not Having Soul__
#     - __Color__

# %% [markdown]
# ## 3. Project Approach<a class="anchor" id="section3"></a>
# - The project shall be carried out in the steps enumerated below.
# - To make the process more relaistic, the train data set is further split into train and test set at the very begining. Therafter, Data processing, preperation and EDA is carried out only on train set.
# - Following the above, test set will be processed and prepared for prediction
# - This will be followed by data transformation, modelling and evaluation.
# - Following models are being considered for the purpose of this project
# - __Superwised Approach__
#     - __Basic Algorithms__
#         - __Logist Regression Algorithm__
#         - __Decision Tree Algorithm__
#         - __Naive Bayes Algorithm__
#         - __KNN Algorithm__
#     - __Bagging Classifiers__
#         - __Random Forest Classifier__
#         - __Bagging Classifier__
#         - __Voting Classifier__
#     - __Boosting Classifiers__
#          - __ADA Boost Classifier__
#          - __Bagging Classifier__
#          - __Gradient Booslt Classifier__
#     - __Stacking Classfier__
#          - __Stacking Classifier__
# - __Unsupervised Approach__
#      - __K Means Clustering__
# - Model Evaluation will be carried out by comapring the __accuracy__ of each model.
# - Following the selection of th ebest fit model, it will be used on test data set to predict the type of creautres.
# - Predicted reslults will be combined with the test data.
# - Final data set will be stored as .csv file.

# %% [markdown]
# ## 4. Importing Libraries and Function<a class="anchor" id="section4"></a>

# %%
# !pip install xgboost

# %%
conda install -c conda-forge xgboost
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pandas and Numpy
import pandas as pd
import numpy as np
import datetime as dt
import os

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
import pandas.plotting
from pandas.plotting import andrews_curves

# Satistics
from scipy.stats import zscore
from scipy.stats import norm, boxcox
from scipy import stats

# Modeling: Prerequisites
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_selection import SelectFromModel
from yellowbrick.model_selection import FeatureImportances

# Models
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB     
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
                                                                     
from sklearn.ensemble import RandomForestClassifier                 
from sklearn.ensemble import GradientBoostingClassifier             
from sklearn.ensemble import StackingClassifier                    
from sklearn.ensemble import VotingClassifier                      
from sklearn.ensemble import BaggingClassifier                       
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb
 

# Model Evaluation
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve                  
from sklearn.metrics import classification_report                   
from sklearn.metrics import plot_confusion_matrix      
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## 5. Creating Custom Functions<a class="anchor" id="section5"></a>
# - These functions have been created to ease of use in this notebook

# %%
# Plot_c_matrix function will enable ploting of confusion matrix of both test and train data 
# side by side for better visibility

def plot_c_matrix(model, title,X_trains,X_tests):
    fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, sharex = False, figsize=(20,7))
    plot_confusion_matrix(estimator = model, X = X_trains, y_true = y_train, values_format = '.7g', cmap = 'YlGnBu', ax = ax1)
    plot_confusion_matrix(estimator = model, X = X_tests, y_true = y_test, values_format = '.7g', cmap = 'YlGnBu', ax = ax2)
    
    ax1.set_title(label = 'Train Data', size = 14, color='blue', fontweight='bold')
    ax2.set_title(label = 'Test Data', size = 14, color='blue', fontweight='bold')
    
    ax1.set_ylabel('Actual', size = 14, color='green', fontweight='bold')
    ax2.set_ylabel('Actual', size = 14, color='green', fontweight='bold')
    
    ax1.tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')
    ax1.tick_params(axis="y", labelsize=14, labelcolor="purple", width='bold')
    ax2.tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')
    ax2.tick_params(axis="y", labelsize=14, labelcolor="purple", width='bold')
    
    ax1.set_xlabel('Predicted', size = 14, color='green', fontweight='bold')
    ax2.set_xlabel('Predicted', size = 14, color='green', fontweight='bold')
   
    ax1.grid(b = False)
    ax2.grid(b = False)
    plt.suptitle(t = 'Confusion Matrix :'+ title, size = 16,color='red', fontweight='bold' )
    plt.show()
    return()

# %%
#cal_score function will enable printing all relevent scores and classifiaction report for both test and train data

def cal_scores(y_test, y_test_pred,y_train, y_train_pred, model):
    print('\nAccuracy Test,  ' + model +  ': {:.4f}'.format(accuracy_score(y_test, y_test_pred)))
    print('Accuracy Train, ' + model +  ': {:.4f}\n'.format(accuracy_score(y_train, y_train_pred)))
    
    print('\nTest Data Set')
    print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_test_pred, average='micro')))
    print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_test_pred, average='micro')))
    print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_test_pred, average='micro')))
    
    print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_test_pred, average='macro')))
    print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_test_pred, average='macro')))
    print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_test_pred, average='macro')))
    
    print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_test_pred, average='weighted')))
    print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_test_pred, average='weighted')))
    print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_test_pred, average='weighted')))
    
    print('\nTrain Data Set')
    print('Micro Precision: {:.2f}'.format(precision_score(y_train, y_train_pred, average='micro')))
    print('Micro Recall: {:.2f}'.format(recall_score(y_train, y_train_pred, average='micro')))
    print('Micro F1-score: {:.2f}\n'.format(f1_score(y_train, y_train_pred, average='micro')))
    
    print('Macro Precision: {:.2f}'.format(precision_score(y_train, y_train_pred, average='macro')))
    print('Macro Recall: {:.2f}'.format(recall_score(y_train, y_train_pred, average='macro')))
    print('Macro F1-score: {:.2f}\n'.format(f1_score(y_train, y_train_pred, average='macro')))
    
    print('Weighted Precision: {:.2f}'.format(precision_score(y_train, y_train_pred, average='weighted')))
    print('Weighted Recall: {:.2f}'.format(recall_score(y_train, y_train_pred, average='weighted')))
    print('Weighted F1-score: {:.2f}'.format(f1_score(y_train, y_train_pred, average='weighted')))
    
    print('\nClassification Report\n')
    print('                    Training Report          ')
    print(classification_report(y_train, y_train_pred))
    print('                    Testing Report           ')
    print(classification_report(y_test, y_test_pred))
    return()

# %%
# Classify function will run classification algorithms as given in the "clf_list" and return a dtaframe with accuracy score 
# of test and train data set in each algorithm
# It will do the .fit, > predict and append scores to a pre defiend list (test_Scores, train_scores)
# Then it returns a data frame, datafram has bee declared global

def classify(clf_list):
    for clf in clf_list:
        clf.fit(X_trains, y_train)
        clf.predict(X_trains)
        clf.predict(X_tests)
    
        clf.score(X_trains, y_train)
        clf.score(X_tests, y_test)
        
        train_scores.append(np.round(clf.score(X_trains, y_train), decimals=2))
        test_scores.append(np.round(clf.score(X_tests, y_test), decimals=2))
        clf_names.append(clf.__class__.__name__)
        
        # Decalred the accuracy_frame as global variable so as to enable further use of the data frame beyond the function
        global accuracy_frame 
        
        accuracy_frame = pd.DataFrame(data={'Train Accuracy': train_scores, 'Test Accuracy': test_scores},index=clf_names)

    return accuracy_frame

# %%
# This function will retun a df with missing values and its percentage
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    return pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# %% [markdown]
# ## 6. Data Preprocessing<a class="anchor" id="section6"></a>
# - Load Data
# - Split data to Train and Test
# - Check for missing data
# - Check for dtypes
# - Describe data

# %% [markdown]
# ### 6.1 Data Loading<a class="anchor" id="section61"></a>
# - Iris data base was downloaded into the local folder as csv file and is loaded into dataframe ir
# - There are total of 150 rows in the dataset

# %%
#Load train data set
train_data =pd.read_csv('/Users/jojojacob/Downloads/ghouls_train.csv')
print(train_data.shape)
# Out:
# (371, 7)

# %%
# Load the test data set
test_data =pd.read_csv('/Users/jojojacob/Downloads/ghouls_test.csv')
print(test_data.shape)
# Out:
# (529, 6)

# %%
train_data.head(2)
# Out:
#    id  bone_length  rotting_flesh  hair_length  has_soul  color    type
# 0   0     0.354512       0.350839     0.465761  0.781142  clear   Ghoul
# 1   1     0.575560       0.425868     0.531401  0.439899  green  Goblin

# %%
test_data.head(2)
# Out:
#    id  bone_length  rotting_flesh  hair_length  has_soul  color
# 0   3     0.471774       0.387937     0.706087  0.698537  black
# 1   6     0.427332       0.645024     0.565558  0.451462  white

# %% [markdown]
# ### 6.2  Data Preperation<a class="anchor" id="section62"></a>
# - Split ghouls_train to train and test
#  - g_train
#  - g_test
# - Check Missing Data
# - Check dtypes consistency
# - Dwscribe Data

# %%
#Split the train data further into train and test
# Ratio is 80:20
g_train, g_test = train_test_split(train_data, test_size=0.2, random_state=2)
print('Shape of g_train :', g_train.shape)
print('Shape of g_test  :', g_test.shape)
# Out:
# Shape of g_train : (296, 7)
# Shape of g_test  : (75, 7)

# %%
# Gain basic inforamtion on data
g_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 296 entries, 284 to 168
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             296 non-null    int64
#  1   bone_length    296 non-null    float64
#  2   rotting_flesh  296 non-null    float64
#  3   hair_length    296 non-null    float64
#  4   has_soul       296 non-null    float64
#  5   color          296 non-null    object
#  6   type           296 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 18.5+ KB

# %%
# Check for missing data
missing_data(g_train)
# Out:
#                Total  Percent
# type               0      0.0
# color              0      0.0
# has_soul           0      0.0
# hair_length        0      0.0
# rotting_flesh      0      0.0
# bone_length        0      0.0
# id                 0      0.0

# %%
summary = g_train.describe().transpose()
summary
# Out:
#                count        mean         std       min         25%  \
# id             296.0  449.429054  267.462239  0.000000  202.750000
# bone_length    296.0    0.435842    0.130522  0.100945    0.348314
# rotting_flesh  296.0    0.503676    0.153758  0.095687    0.406789
# hair_length    296.0    0.530835    0.169234  0.134600    0.408814
# has_soul       296.0    0.468281    0.172911  0.009402    0.348981
#
#                       50%         75%         max
# id             473.000000  684.250000  897.000000
# bone_length      0.439598    0.517018    0.817001
# rotting_flesh    0.499192    0.608543    0.932466
# hair_length      0.538824    0.651876    0.965569
# has_soul         0.463149    0.594780    0.935721

# %%
g_train.nunique()
# Out:
# id               296
# bone_length      296
# rotting_flesh    296
# hair_length      296
# has_soul         296
# color              6
# type               3
# dtype: int64

# %% [markdown]
# ### 6.3  Obsevations: Data Preperation<a class="anchor" id="section63"></a>
# - Iris Data has 150 rows and 6 columns
#     - Train Set is named ir_train
#     - Test Set  is named ir_test
# - Train set has __120__ rows and test set has __30__ rows
# - Id Column is an identification variable and is dropped
# - Species is the target variable
# - There are four exploratory variables
#     -__Sepal Length__
#     -__Sepal Width__
#     -__Petal Length__
#     -__Petal Width__
# - There are no missing values
# - The distribution of exlporatory variables seems normal

# %% [markdown]
# ## 7. Data Processing<a class="anchor" id="section67"></a>
# - Drop Unwanted columns
# - Rename columns for ease of use and understanding
# - Process individual Columns fo data consistency, typos and other errors
#     - Unique values count
#     - Unique values
#     - Plot numerical values
# - Check for correlation between exploratory variables

# %% [markdown]
# ### 7.1 Basic Processing<a class="anchor" id="section71"></a>

# %%
# Id is an identification variable and hence being dropped
g_train.drop('id', axis = 1, inplace = True)

# %%
g_train.columns
# Out:
# Index(['bone_length', 'rotting_flesh', 'hair_length', 'has_soul', 'color',
#        'type'],
#       dtype='object')

# %% [markdown]
# ### 7.2 Processing Individual Columns<a class="anchor" id="section72"></a>

# %% [markdown]
# #### 7.2.1 Bone Length (bone_length)<a class="anchor" id="section721"></a>

# %%
# # of Unique Vaules
g_train['bone_length'].nunique()
# Out:
# 296

# %%
# Unique Values
g_train['bone_length'].unique()
# Out:
# array([0.76135541, 0.42496899, 0.48962771, 0.48913239, 0.39557569,
#        0.39071213, 0.35155867, 0.40683354, 0.4717645 , 0.50758291,
#        0.30419779, 0.52378864, 0.33290537, 0.24885445, 0.81700143,
#        0.32703136, 0.58622658, 0.45637104, 0.47632004, 0.41135323,
#        0.43168521, 0.14507076, 0.35508702, 0.27502114, 0.39698833,
#        0.60089787, 0.52853561, 0.37647295, 0.48271618, 0.47689162,
#        0.42449277, 0.36256683, 0.4315008 , 0.45813186, 0.20307343,
#        0.44043173, 0.54008763, 0.42721754, 0.62241365, 0.46542332,
#        0.24641476, 0.48863219, 0.4165772 , 0.45693516, 0.58454323,
#        0.49960965, 0.30875469, 0.62765237, 0.39983896, 0.4440056 ,
#        0.33657342, 0.32966821, 0.34628345, 0.28502209, 0.1689085 ,
#        0.33213428, 0.5861773 , 0.45075932, 0.35083808, 0.38105751,
#        0.17360695, 0.34334961, 0.43906329, 0.18778053, 0.22479754,
#        0.2880501 , 0.4510851 , 0.50222903, 0.39725803, 0.5661166 ,
# ...

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(g_train, x = 'bone_length', kde=True, color='blue')
# Out:
# <AxesSubplot:xlabel='bone_length', ylabel='Count'>

# %% [markdown]
# #### 7.2.2 Rotting Flesh (rotting_flesh)<a class="anchor" id="section722"></a>

# %%
# # of Unique Vaules
g_train['rotting_flesh'].nunique()
# Out:
# 296

# %%
# Unique Vaules
g_train['rotting_flesh'].unique()
# Out:
# array([0.33147995, 0.24029871, 0.55218334, 0.48130398, 0.79859021,
#        0.3350694 , 0.47107817, 0.45531029, 0.801465  , 0.79962326,
#        0.26690423, 0.65731673, 0.49489548, 0.55487176, 0.40080796,
#        0.6084808 , 0.46428432, 0.45620752, 0.28622608, 0.49262125,
#        0.43895927, 0.39506013, 0.44402449, 0.68997493, 0.611109  ,
#        0.41172958, 0.58913977, 0.64637232, 0.56148147, 0.47859235,
#        0.27302559, 0.63975342, 0.3495549 , 0.39175983, 0.16553895,
#        0.30949782, 0.48153208, 0.5454233 , 0.49761411, 0.09568665,
#        0.4095959 , 0.54847307, 0.45852253, 0.62714121, 0.59308194,
#        0.43647478, 0.70503412, 0.84004926, 0.72397098, 0.42418899,
#        0.24309196, 0.33199874, 0.15874186, 0.49231535, 0.64886647,
#        0.57732104, 0.46953427, 0.54264867, 0.45463695, 0.70416823,
#        0.58961287, 0.39745003, 0.49051486, 0.73649105, 0.60690812,
#        0.60377972, 0.46450787, 0.50439893, 0.6729848 , 0.8758618 ,
# ...

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(g_train, x = 'rotting_flesh', kde=True, color='green')
# Out:
# <AxesSubplot:xlabel='rotting_flesh', ylabel='Count'>

# %% [markdown]
# #### 7.2.3 Hair Length  (hair_length)<a class="anchor" id="section723"></a>

# %%
# # of Unique Vaules
g_train['hair_length'].nunique()
# Out:
# 296

# %%
# Unique Vaules
g_train['hair_length'].unique()
# Out:
# array([0.86106009, 0.33867787, 0.67962415, 0.48269135, 0.33082189,
#        0.55610946, 0.48445778, 0.28700752, 0.23061906, 0.33452002,
#        0.52722488, 0.81897924, 0.47478814, 0.50631961, 0.43704672,
#        0.31046862, 0.59977386, 0.23633154, 0.48884337, 0.43774532,
#        0.23921249, 0.33388353, 0.53534448, 0.58651278, 0.50721435,
#        0.7177273 , 0.65121662, 0.60944908, 0.53142288, 0.40363033,
#        0.39365693, 0.53624757, 0.46893645, 0.6605899 , 0.29950696,
#        0.20305693, 0.71747958, 0.63965001, 0.46541869, 0.40679052,
#        0.53864248, 0.59862087, 0.76833305, 0.46379365, 0.68116576,
#        0.59175202, 0.64346763, 0.41481606, 0.3605798 , 0.54961321,
#        0.25345886, 0.39642867, 0.71498702, 0.72067826, 0.30392741,
#        0.44585962, 0.7643118 , 0.7952066 , 0.78300089, 0.51474905,
#        0.36343855, 0.47887602, 0.65472141, 0.3443479 , 0.4467213 ,
#        0.47395616, 0.50581862, 0.26354896, 0.55166434, 0.41859367,
# ...

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(g_train, x = 'hair_length', color='red', kde=True)
# Out:
# <AxesSubplot:xlabel='hair_length', ylabel='Count'>

# %% [markdown]
# #### 7.2.4 Has Soul  (has_soul)<a class="anchor" id="section724"></a>

# %%
# # of Unique Vaules
g_train['has_soul'].nunique()
# Out:
# 296

# %%
# Unique Vaules
g_train['has_soul'].unique()
# Out:
# array([0.7358969 , 0.08892447, 0.62703024, 0.46008068, 0.20400386,
#        0.78421658, 0.46532788, 0.64168054, 0.28506656, 0.34440348,
#        0.38671341, 0.62450389, 0.51494366, 0.08940215, 0.64823017,
#        0.35669897, 0.85675682, 0.30048573, 0.41146064, 0.27616312,
#        0.47181956, 0.28677342, 0.24634672, 0.40274855, 0.17964219,
#        0.53164056, 0.41217567, 0.38429295, 0.56065878, 0.54458665,
#        0.36390733, 0.42767849, 0.19441331, 0.63568919, 0.42580223,
#        0.194105  , 0.69478396, 0.60480097, 0.45914075, 0.36434107,
#        0.08482884, 0.54456591, 0.65400642, 0.43621605, 0.93572133,
#        0.65962183, 0.58374997, 0.48861721, 0.36391248, 0.44751719,
#        0.54502342, 0.50714231, 0.32267575, 0.68988481, 0.25543993,
#        0.4095255 , 0.28085369, 0.73942852, 0.6744786 , 0.43653695,
#        0.61415775, 0.62182288, 0.40531936, 0.34630625, 0.41223257,
#        0.40829382, 0.50900963, 0.12168669, 0.159367  , 0.63643782,
# ...

# %%
# Distribution of Sepal Length
plt.figure(figsize=(8,6))
sns.histplot(g_train, x = 'has_soul', color='purple', kde=True)
# Out:
# <AxesSubplot:xlabel='has_soul', ylabel='Count'>

# %% [markdown]
# #### 7.2.5 Color  (color)<a class="anchor" id="section724"></a>

# %%
# # of Unique Vaules
g_train['color'].nunique()
# Out:
# 6

# %%
# Unique Vaules
g_train['color'].unique()
# Out:
# array(['green', 'white', 'black', 'clear', 'blood', 'blue'], dtype=object)

# %%
g_train['color'].value_counts()
# Out:
# white    110
# clear     98
# green     34
# black     28
# blue      15
# blood     11
# Name: color, dtype: int64

# %%
g_train['color'].value_counts().plot(kind="barh", color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 7.2.6 Type (type): Target Variable<a class="anchor" id="section725"></a>

# %%
# # of Unique Vaules
g_train['type'].nunique()
# Out:
# 3

# %%
# Unique Vaules
g_train['type'].unique()
# Out:
# array(['Ghoul', 'Ghost', 'Goblin'], dtype=object)

# %%
g_train['type'].value_counts()
# Out:
# Ghoul     103
# Goblin    101
# Ghost      92
# Name: type, dtype: int64

# %%
g_train['type'].value_counts().plot(kind="barh", color='purple')
# Out:
# <AxesSubplot:>

# %%
# Checking for multicolinearity among X variables in train data set
# use heatmap
plt.figure (figsize=(10,7))
correlation_g_train = sns.heatmap(g_train.corr(), annot = True, cmap='PiYG')
plt.xlabel(xlabel = 'Features', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
plt.ylabel(ylabel = 'Features', size = 14, fontweight = 'bold', fontsize = 14, color = 'Blue')
plt.title(label = 'Heat Map', size = 14, fontweight = 'bold', fontsize = 20, color = 'blue')
plt.tick_params(axis="x", labelsize=14, labelcolor="purple", rotation = 0)
plt.tick_params(axis="y", labelsize=14, labelcolor="green", rotation = 0)
correlation_g_train
# Out:
# <AxesSubplot:title={'center':'Heat Map'}, xlabel='Features', ylabel='Features'>

# %% [markdown]
# ### 7.3 Observations<a class="anchor" id="section73"></a>
# - Data is consistent
# - Distribution of Sepal Length and Width are normal, whereas that of Petal length and width are not normal
# - Correlations
#     - Sepal Length is highly corelated to petal width and petal length
#     - Sepal Length has no correlation with Sepal Width
#     - Sepal Width has no correlation with any other data

# %% [markdown]
# ## 8. EDA<a class="anchor" id="section8"></a>

# %% [markdown]
# ### 8.1 Distibution of Count of Types of Creatures<a class="anchor" id="section81"></a>

# %%
g_train["type"].value_counts()
# Out:
# Ghoul     103
# Goblin    101
# Ghost      92
# Name: type, dtype: int64

# %%
# Count plot and doughnut plot are used to show distribution of species in data set
fig, ax = plt.subplots(1,2, figsize = [15, 8])

space = [0.0,0.01,0.01]
colors = ['#ff9999','#66b3ff','#99ff99']

sns.countplot(x = 'type', data = g_train, ax=ax[0],color='orange')
g_train['type'].value_counts().plot(kind = 'pie', ax=ax[1], explode = space, fontsize = 14, autopct = '%3.1f%%', wedgeprops = dict(width=0.25), 
                                      shadow = True, startangle = 160, figsize = [15, 8], legend = True, colors=colors)
plt.legend(g_train.type)

plt.suptitle(t = 'Frequency & Proportion of Creature Type', color='red', y = 1.02, size = 16)

ax[0].set_xlabel(xlabel = 'Type', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0].set_ylabel(ylabel = 'Count', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0].set_title(label = 'Count of Types', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0].tick_params(axis="x", labelsize=14, labelcolor="purple", rotation = 0)
space = [0.0,0.05,0.05]

ax[1].set_title(label = 'Proportion of Types', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1].set_ylabel('', size = 14)
plt.tight_layout(pad = 3.0)

plt.show()

# %% [markdown]
# ### 8.2 Comparison of Features of each Type using Histplot <a class="anchor" id="section82"></a>

# %%
f, ax = plt.subplots(2,2, figsize=(15,9))
sns.histplot(data=g_train, x="bone_length", hue="type", palette ='rainbow', kde=True,ax=ax[0,0])
sns.histplot(data=g_train, x="hair_length", hue="type", palette ='flare_r',kde=True,ax=ax[1,0])
sns.histplot(data=g_train, x="rotting_flesh", hue="type", palette ='ocean',kde=True,ax=ax[0,1])
sns.histplot(data=g_train, x="has_soul", hue="type", palette ='winter',kde=True,ax=ax[1,1])

plt.suptitle(t = 'Feature Comparison', color='red', y = 1.02, size = 16)

ax[0,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_title(label = 'Bone Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[0,1].set_xlabel(xlabel = 'Frequency', size = 14, fontweight = 'bold', fontsize = 14, color = 'green')
ax[0,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].set_title(label = 'Rotting Flesh', size = 16, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_title(label = 'Hair Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,1].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_title(label = 'Has Soul', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')
plt.show()

# %% [markdown]
# ### Observation
# - Within each species the features are normally distributed
# - Iris Setosa shows significant vareiation in Petal and Sepal length compared to other two species.
# - Iris Setosa shows notable diffrence in petal width compared to other two species.

# %% [markdown]
# ### 8.3 Anomaly Detection in Features<a class="anchor" id="section83"></a>

# %% [markdown]
# ### 8.3.1 Checking for Anomalies in Features using Boxplots<a class="anchor" id="section831"></a>

# %%
# Using Box Plot to find outliers if any
g_train.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# ### 8.3.2 Checking for Anomalies in Features within Species using Boxplots<a class="anchor" id="section832"></a>

# %%
f, ax = plt.subplots(2,2, figsize=(20,10))

#sns.set(style="whitegrid", palette="GnBu_d", rc={'figure.figsize':(11.7,8.27)})

sns.boxplot(x="type", y="bone_length", data=g_train, ax = ax[0,0])
sns.boxplot(x="type", y="rotting_flesh", data=g_train, ax = ax[0,1])
sns.boxplot(x="type", y="hair_length", data=g_train, ax = ax[1,0])
sns.boxplot(x="type", y="has_soul", data=g_train, ax = ax[1,1])

plt.suptitle(t = 'Features', color='red', y = 1.02, size = 16)

ax[0,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].set_title(label = 'Bone Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[0,1].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].set_title(label = 'Rotting Flesh', size = 16, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[0,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,0].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_ylabel(ylabel = 'Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].set_title(label = 'Hair Length', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,0].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')

ax[1,1].set_xlabel(xlabel = '', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_ylabel(ylabel = 'Width', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].set_title(label = 'Has Soul', size = 14, fontweight = 'bold', fontsize = 14, color = 'blue')
ax[1,1].tick_params(axis="x", labelsize=14, labelcolor="purple", width='bold')


# Show the plot
plt.show()

# %% [markdown]
# #### Observation
# - There are no major outliers in any of the the features between features
# - There are no major outliers in any feature within each species.

# %% [markdown]
# ### 8.4. Checking for Corelation between Features within Types using Pair & Scatter Plots<a class="anchor" id="section84"></a>

# %% [markdown]
# ### 8.4.1 Checking for Corelation between Features within using Pair Plots<a class="anchor" id="section841"></a>

# %%
sns.pairplot(g_train, hue="type", kind='reg', palette="winter", markers=["o", "s", "D"])
sns.despine()
plt.show()

# %% [markdown]
# ### 8.4.2 Checking Corelation between Features: Reg Plots<a class="anchor" id="section842"></a>

# %%
plt.figure(figsize=(15,12))
plt.subplot(2,2,1)
sns.regplot(x='bone_length', y= 'hair_length', data= g_train, color='red');
sns.regplot(x='bone_length', y= 'has_soul', data= g_train, color='green');
sns.regplot(x='bone_length', y= 'rotting_flesh', data= g_train, color='blue');
plt.title('Bone Length Vs Other Features', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('Bone Length', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Other Features', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.legend(labels=['bone length vs hair length','bone length vs has soul','bone length vs rotting flesh'], frameon =True)

plt.subplot(2,2,2)
sns.regplot(x='rotting_flesh', y= 'hair_length', data= g_train, color='red');
sns.regplot(x='rotting_flesh', y= 'has_soul', data= g_train, color='orange');
#sns.regplot(x='rotting_flesh', y= 'petal_length', data= ghouls_train, color='purple');
plt.title('Rotting Flesh Vs Other Features', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('Rotting Flesh', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Other Features', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.legend(labels=['Rotting Flesh vs Hair Length','Rotting Flesh vs Has Soul'], frameon =True)

# %% [markdown]
# #### Observation
# - Correlation or lack of it between features are seen to be similar between and within species
# - Sepal Length has high correlation with Petal Length
# - Sepal Length has no correlation to Sepal Width
# - Sepal Length has no correlation to Petal Width
# - Sepal Width  has some negative correlation to Petal Width
# - Petal Width  has high correlation to Petal Length

# %% [markdown]
# ### 8.5 Understanding  Features<a class="anchor" id="section85"></a>

# %% [markdown]
# ### 8.5.1 Measuring Features across Species: Swarm Plot<a class="anchor" id="section851"></a>

# %%
sns.set(style="whitegrid", palette="GnBu_d", rc={'figure.figsize':(11,8)})

# "Melt" the dataset
g_train1 = g_train.drop('color', axis=1)
g_train1 = pd.melt(g_train1, "type", var_name="measurement")


# Draw a categorical scatterplot
sns.swarmplot(x="measurement", y="value", hue="type",palette="flare", data=g_train1)

plt.title('Measurement of Features Within Each Typw: Swarm Plot', color = 'red', fontweight = 'bold', fontsize =14)
plt.xlabel('Measurement', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Value', color = 'blue', fontweight = 'bold', fontsize =14)
plt.tick_params(axis='x',labelcolor='purple', labelsize=14)
plt.tick_params(axis='y',labelcolor='green', labelsize=14)
plt.legend(frameon=True,title='Species')

plt.show()

# %% [markdown]
# ### 8.5.2 Measuring Features within Species: Violin Plot<a class="anchor" id="section852"></a>

# %%
plt.figure(figsize=(15,10))
plt.suptitle(t = 'Comparison of Features using Violin Plot', color='red', y = 1.02, size = 16)
plt.subplot(2,2,1)
sns.violinplot(x='type',y='bone_length',data=g_train,palette="rainbow")
plt.title('Sepal Length', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Length', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.subplot(2,2,2)
sns.violinplot(x='type',y='hair_length',data=g_train,palette="rainbow")
plt.title('Sepal Width', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Width', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.subplot(2,2,3)
sns.violinplot(x='type',y='rotting_flesh',data=g_train,palette="rainbow")
plt.title('Petal Length', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Length', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.subplot(2,2,4)
sns.violinplot(x='type',y='has_soul',data=g_train,palette="rainbow")
plt.title('Petal Width', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Width', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)

# %% [markdown]
# #### Observations
# - The class "Iris-sentosa" seems to have less petal,sepal length and petal width.However it has higher sepal width or in other words it's width is varied from low to high but majority on the higher side
# - The class "Iris-virginica"  has high sepal length, petal length, petal width  but medium ranged sepal width.
# - From the above two observations it is understood that "Iris-sentosa"  and "Iris-virginica" is linearly seperable.
# - The class "Iris-versicolor" lies in the mid range for all the attributes.

# %% [markdown]
# ### 8.6 Understanding Data uing Andrews Plot<a class="anchor" id="section86"></a>
# - Most data that are collected are multivariate in nature, and much of them can be regarded as continuous. In the initial stages of analysis, graphic displays can be used to explore the data, but for multivariate data, traditional histograms or two- or three-dimensional scatter plots may miss complex relationships that exist in the data set.
# - A first step in any investigation of data is to create simple summaries and graphs so as to obtain a better understanding of the nature of the data before analysis and also check for outliers or unusual observations. However, the production of univariate or bivariate summary statistics (e.g., means, correlations) or of histograms and two-dimensional scatter plots to graphically display the data may hide more complex relationships existing in the multivariate data set.
# - __Andrews Curve__ is a great tool for analysing the complex relationships in multivariate analysis.
# - It is being used to acertain the possible groups/custers in unsupervised machine learning approch.
# - Formula used is __x(t)= x1 2 + x2 sin(t)+ x3 cos(t)+ x4 sin(2t)+ x5 cos(2t)+ x6 sin(3t)+ x7 cos(3t)+....__

# %%
g_dummies = pd.get_dummies(g_train, columns=['color'], drop_first =True)
g_dummies
# Out:
#      bone_length  rotting_flesh  hair_length  has_soul    type  color_blood  \
# 284     0.761355       0.331480     0.861060  0.735897   Ghoul            0
# 66      0.424969       0.240299     0.338678  0.088924   Ghost            0
# 179     0.489628       0.552183     0.679624  0.627030   Ghoul            0
# 114     0.489132       0.481304     0.482691  0.460081  Goblin            0
# 257     0.395576       0.798590     0.330822  0.204004   Ghost            0
# ..           ...            ...          ...       ...     ...          ...
# 299     0.354047       0.540752     0.571210  0.243775   Ghost            0
# 22      0.374449       0.384183     0.675868  0.414700  Goblin            0
# 72      0.348991       0.564233     0.481190  0.177172   Ghost            0
# 15      0.500197       0.438418     0.532530  0.665522   Ghoul            0
# 168     0.403995       0.682687     0.372529  0.499520   Ghost            0
#
#      color_blue  color_clear  color_green  color_white
# ...

# %%
andrews_curves(g_dummies, "type")
plt.title("Andrew's Curve", color = 'blue', fontweight = 'bold', fontsize =14)
plt.legend(framealpha=1, frameon=True,title='Types', fontsize=14)

# %% [markdown]
# #### Observations
# - There are 3 distinct classes/groups in the data set
# - There are no ouliers in the dataset
# - Class/Group fromation is fairly straight forward and simple

# %% [markdown]
# ## 9 Modelling<a class="anchor" id="section9"></a>

# %% [markdown]
# ### 9.1 Preparing the Test Data<a class="anchor" id="section91"></a>
# - The Test data has to processed in the same manner as that of train data.

# %%
g_test.head()
# Out:
#       id  bone_length  rotting_flesh  hair_length  has_soul  color    type
# 55   115     0.678519       0.476821     0.477152  0.489358   blue  Goblin
# 94   208     0.619468       0.465614     0.367914  0.535858  black  Goblin
# 108  258     0.440855       0.432710     0.643989  0.322236  white  Goblin
# 228  564     0.475316       0.529210     0.307358  0.230361  clear   Ghost
# 24    45     0.687256       0.301576     0.761949  0.513779  clear   Ghoul

# %%
g_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75 entries, 55 to 150
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             75 non-null     int64
#  1   bone_length    75 non-null     float64
#  2   rotting_flesh  75 non-null     float64
#  3   hair_length    75 non-null     float64
#  4   has_soul       75 non-null     float64
#  5   color          75 non-null     object
#  6   type           75 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 4.7+ KB

# %%
missing_data(g_test)
# Out:
#                Total  Percent
# type               0      0.0
# color              0      0.0
# has_soul           0      0.0
# hair_length        0      0.0
# rotting_flesh      0      0.0
# bone_length        0      0.0
# id                 0      0.0

# %%
# Droppig columns to match train data set
g_test.drop('id', axis = 1, inplace = True)
#ghouls_test.columns = ir_train.columns.str.lower()
#ghouls_test.rename(columns={'sepallengthcm':'sepal_length','sepalwidthcm':'sepal_width','petallengthcm':'petal_length','petalwidthcm':'petal_width'}, inplace=True)

# %%
g_test.head(2)
# Out:
#     bone_length  rotting_flesh  hair_length  has_soul  color    type
# 55     0.678519       0.476821     0.477152  0.489358   blue  Goblin
# 94     0.619468       0.465614     0.367914  0.535858  black  Goblin

# %% [markdown]
# ### 9.2 Feature Selection<a class="anchor" id="section92"></a>

# %%
# There are various ways to do the feature selection, here is one
# Train Data
X_train = g_train.loc[:, g_train.columns != 'type']
y_train = g_train['type']

#Test Data
X_test = g_test.loc[:, g_test.columns != 'type']
y_test = g_test['type']

# %%
print('X_train :', X_train.shape)
print('y_train :', y_train.shape)
print('X_test  :', X_test.shape)
print('y_test  :', y_test.shape)
# Out:
# X_train : (296, 5)
# y_train : (296,)
# X_test  : (75, 5)
# y_test  : (75,)

# %%
X_train = pd.get_dummies(X_train, columns=['color'], drop_first =True)
X_test  = pd.get_dummies(X_test, columns=['color'], drop_first =True)

# %% [markdown]
# ### 9.3 Scaling of Data<a class="anchor" id="section93"></a>
# - Scaling of data is essential and prerequesite to sucessful model creation.
# - __Standard Scalar__ is used.

# %%
#fitting is determining what to do
#transforming - actually doing it

scaler = StandardScaler() # cleate an object
scaler.fit(X_train) #what should be the multiplication factor
X_trains = scaler.transform(X_train) #actually multiplies
X_tests  = scaler.transform(X_test)

# %% [markdown]
# ### 9.4 Modelling using Supervised Approach<a class="anchor" id="section94"></a>
# - __Basic Algorithms__
#     - __Logistic Regression__
#     - __Support Vector Classifier__
#     - __Decision Tree Classifier__
#     - __KNN Classifier__
# - __Bagging Algorithms__
#     - __Random Forest Classifier__
#     - __Bagging Classifier__
#     - __Voting Classifier__
# - __Boosting Algorithms__
#     - __ADA Boost Classifier__
#     - __Gradient Boost Classifier__
# - __Stacking Algorithms__
#     - __Stacking Classifier__

# %% [markdown]
# ### 9.4.1 Initializing Models<a class="anchor" id="section941"></a>

# %%
# Initialize the Models

# Basic Classifier Algorithms
log_clf    = LogisticRegression(class_weight='balanced')
sv_clf     = SVC(class_weight='balanced', probability=True)
dt_clf     = DecisionTreeClassifier(class_weight='balanced')
knn_clf    = KNeighborsClassifier(n_neighbors=5)

#Bagging Algorithms
rf_clf     = RandomForestClassifier(n_estimators=500, class_weight='balanced', n_jobs=-1)
bag_clf    = BaggingClassifier(base_estimator=dt_clf, n_estimators=500, n_jobs=-1)
voting_clf = VotingClassifier(estimators=[('lr', log_clf), ('rf', rf_clf), ('dt', dt_clf), ('svc', sv_clf)], voting='soft')

#Boosting Algorithms
ada_clf    = AdaBoostClassifier(base_estimator=dt_clf, n_estimators=500)
gb_clf     = GradientBoostingClassifier(n_estimators=500)

# Stacking Alogrithm
# Creating a collection of estimators
estimators = [('logistic', LogisticRegression(class_weight='balanced', n_jobs=-1)), 
              ('svc', SVC(class_weight='balanced', probability=True)),
              ('knn', KNeighborsClassifier(n_jobs=-1)),
              ('randomforest', RandomForestClassifier(class_weight='balanced', n_jobs=-1))]

# Setting StackingClassifier with initiated estimators and a final estimator
stack_clf = StackingClassifier(estimators=estimators, 
                               final_estimator=GradientBoostingClassifier(), 
                               n_jobs=-1, cv=5)

# %% [markdown]
# ### 9.4.2 Predicting using Models<a class="anchor" id="section941"></a>

# %%
# %%time
train_scores = []
test_scores  = []
clf_names    = []

clf_list = [log_clf, sv_clf, dt_clf, knn_clf, rf_clf, bag_clf, voting_clf, ada_clf, gb_clf, stack_clf]

classify(clf_list)
# Out:
# CPU times: user 7.56 s, sys: 920 ms, total: 8.48 s
# Wall time: 18.3 s
#                             Train Accuracy  Test Accuracy
# LogisticRegression                    0.73           0.87
# SVC                                   0.76           0.80
# DecisionTreeClassifier                1.00           0.64
# KNeighborsClassifier                  0.78           0.76
# RandomForestClassifier                1.00           0.75
# BaggingClassifier                     1.00           0.84
# VotingClassifier                      1.00           0.79
# AdaBoostClassifier                    1.00           0.64
# GradientBoostingClassifier            1.00           0.75
# StackingClassifier                    0.78           0.80

# %% [markdown]
# ### 9.5 Unsupervised Approches<a class="anchor" id="section95"></a>

# %% [markdown]
# ### 9.5.1 K Means Clustering<a class="anchor" id="section952"></a>

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture #For GMM clustering

# %%
g_train.head()
# Out:
#      bone_length  rotting_flesh  hair_length  has_soul  color    type
# 284     0.761355       0.331480     0.861060  0.735897  green   Ghoul
# 66      0.424969       0.240299     0.338678  0.088924  white   Ghost
# 179     0.489628       0.552183     0.679624  0.627030  black   Ghoul
# 114     0.489132       0.481304     0.482691  0.460081  white  Goblin
# 257     0.395576       0.798590     0.330822  0.204004  white   Ghost

# %%
g_k = g_train[['bone_length','hair_length','rotting_flesh','has_soul']]

# %%
#Finding the optimum number of clusters for k-means classification
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X_trains)
    wcss.append(kmeans.inertia_)

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
kmeans = kmeans.fit(X_trains)
y_pred_train_kmeans = kmeans.predict(X_trains)
y_pred_test_kmeans  = kmeans.predict(X_tests)

# %%
#Visualising the clusters Train set
fig, ax = plt.subplots(figsize=(8,6))
plt.scatter(X_trains[y_pred_train_kmeans == 0, 0], X_trains[y_pred_train_kmeans == 0, 1], s = 100, c = 'purple', label = 'Cluster 1')
plt.scatter(X_trains[y_pred_train_kmeans == 1, 0], X_trains[y_pred_train_kmeans == 1, 1], s = 100, c = 'orange', label = 'Clsuter 2')
plt.scatter(X_trains[y_pred_train_kmeans == 2, 0], X_trains[y_pred_train_kmeans == 2, 1], s = 100, c = 'green', label  = 'Cluster 3')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')

plt.legend(frameon =True)

# %%
#Visualising the clusters Test set
fig, ax = plt.subplots(figsize=(8,6))
plt.scatter(X_tests[y_pred_test_kmeans == 0, 0], X_tests[y_pred_test_kmeans == 0, 1], s = 100, c = 'purple', label = 'Cluster 1')
plt.scatter(X_tests[y_pred_test_kmeans == 1, 0], X_tests[y_pred_test_kmeans == 1, 1], s = 100, c = 'orange', label = 'Cluster 2')
plt.scatter(X_tests[y_pred_test_kmeans == 2, 0], X_tests[y_pred_test_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')

plt.legend(frameon =True)

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(111, projection='3d')
plt.scatter(X_tests[y_pred_test_kmeans == 0, 0], X_tests[y_pred_test_kmeans == 0, 1], s = 100, c = 'purple', label = 'Cluster 1')
plt.scatter(X_tests[y_pred_test_kmeans == 1, 0], X_tests[y_pred_test_kmeans == 1, 1], s = 100, c = 'orange', label = 'Cluster 2')
plt.scatter(X_tests[y_pred_test_kmeans == 2, 0], X_tests[y_pred_test_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.legend(loc='upper right', frameon = True, title = "Clusters")
#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')
plt.show()

# %% [markdown]
# ### 9.6 Model Evaluation<a class="anchor" id="section96"></a>
# - Create a List of Accuracy and F 1 Scores
# - Append the lists for each model
# - Create a dataframe of Ml Model, Accuracy Score and F 1 Score
# - Compare the values and plot them to find the best model

# %%
plots=accuracy_frame.plot(kind = "bar", color = "rgb")
plt.title('Accuracy Scores for Test and Train Data', color = 'blue', fontweight = 'bold', fontsize =14)
plt.xlabel('ML Models', color = 'blue', fontweight = 'bold', fontsize =14)
plt.ylabel('Accuracy Score', color = 'green', fontweight = 'bold', fontsize =14)
plt.tick_params(labelcolor='purple', labelsize=14)
plt.legend(labels=['Accuracy Scoe: Train Data','Accuracy Scoe: Test Data'],frameon =True,title_fontsize=14)
for bar in plots.patches:
    plt.annotate(format(bar.get_height(), '.2f'), (bar.get_x() + bar.get_width() / 2, 
    bar.get_height()), ha='center', va='center',size=10,weight = "bold", xytext=(0, 8),
    textcoords='offset points')
plots
# Out:
# <AxesSubplot:title={'center':'Accuracy Scores for Test and Train Data'}, xlabel='ML Models', ylabel='Accuracy Score'>

# %%
plot_c_matrix(bag_clf, "Bagging Classifier",X_trains,X_tests)
# Out:
# ()

# %% [markdown]
# ### Observation
# - All the models created has varrying accuracy scores.
# - Highest test accuracy score is of Logistic Regression, however it is seen to be overfitting and hence not selected as the best model.
# - Since the desired accuracy was acheived, optimisation of the models was not done.
# - __Best Fit Model__
#  - __Bagging Classifier__

# %% [markdown]
# ### 10. Test Data Classification <a class="anchor" id="section100"></a>
# - Original Test data given along with train data will be classified.
# - Algorithm with highest accuracy score is used: __bag_clf : Bagging Classifier__
# - Resluts are saved into a csv file: __final_result__

# %% [markdown]
# ### 10.1 Processing Test Data<a class="anchor" id="section101"></a>

# %%
# Checking the original test data
test_data.head()
# Out:
#    id  bone_length  rotting_flesh  hair_length  has_soul  color
# 0   3     0.471774       0.387937     0.706087  0.698537  black
# 1   6     0.427332       0.645024     0.565558  0.451462  white
# 2   9     0.549602       0.491931     0.660387  0.449809  black
# 3  10     0.638095       0.682867     0.471409  0.356924  white
# 4  13     0.361762       0.583997     0.377256  0.276364  black

# %%
# Dropping id Column
testing_data = test_data.drop(['id'], axis = 1, inplace = True)

# %%
# Check for missing data
missing_data(test_data)
# Out:
#                Total  Percent
# color              0      0.0
# has_soul           0      0.0
# hair_length        0      0.0
# rotting_flesh      0      0.0
# bone_length        0      0.0

# %%
# One hot Encoding
testing_data_d = pd.get_dummies(test_data, columns=['color'], drop_first =True)

# %%
testing_data_d.head(2)
# Out:
#    bone_length  rotting_flesh  hair_length  has_soul  color_blood  color_blue  \
# 0     0.471774       0.387937     0.706087  0.698537            0           0
# 1     0.427332       0.645024     0.565558  0.451462            0           0
#
#    color_clear  color_green  color_white
# 0            0            0            0
# 1            0            0            1

# %%
# Scaling Test data using Standard Scaler
scaler = StandardScaler() # cleate an object
testing_data_s = scaler.fit_transform(testing_data_d) #what should be the multiplication factor

# %% [markdown]
# ### 10.2 Prediction on Test Data using Selected Model: Bagging Classifier<a class="anchor" id="section102"></a>

# %%
# Running the selected algorithm and getting output as a dataframe
y_pred = bag_clf.predict(testing_data_s) # running the model
result = pd.DataFrame(y_pred, columns=["type"]) # Converting the results into a dataframe
result.head(2)
# Out:
#      type
# 0   Ghoul
# 1  Goblin

# %% [markdown]
# ### 10.3 Creating and Saving Final Result <a class="anchor" id="section103"></a>

# %%
# Creating the final result by concating the results to the original test datal
final_result=pd.concat([test_data,result],axis =1)
final_result.head(3)
# Out:
#    bone_length  rotting_flesh  hair_length  has_soul  color    type
# 0     0.471774       0.387937     0.706087  0.698537  black   Ghoul
# 1     0.427332       0.645024     0.565558  0.451462  white  Goblin
# 2     0.549602       0.491931     0.660387  0.449809  black   Ghoul

# %%
final_result['type'].value_counts()
# Out:
# Ghost     181
# Ghoul     181
# Goblin    167
# Name: type, dtype: int64

# %%
# Saving the final result dataframe to a csv file
final_result.to_csv("final_result.csv")

# %% [markdown]
# ## 11. Conclusion<a class="anchor" id="section11"></a>

# %% [markdown]
# ### 11.1 Summary<a class="anchor" id="section111"></a>
# - The project was conducted as per the project approch mentioned in section 3.
# - Having done the project, it was seen that the data set presented a simple and straighforward need to classify mythical creatures into three distict types using four attributes.
# - It was seen that the accuracy of test and train data was commensurate and hence there was no underfitting.
# - In this case the data was limited to just 371 rows and hence presented a low number of data points.
# - Models were evaluated using accuracy score
# - __Bagging Classifier__ displayed best fit, though logistic regression model had highest score, it seemed to be overfitting.

# %% [markdown]
# ### 11.2 Limitations of Study<a class="anchor" id="section112"></a>
# - The data set used had only 371 rows out of which only 126 was used to do EDA and train models.
# - EDA was limited as the relation between the variables were fairly straight forward.

# %% [markdown]
# ### 11.3 Lessons Learned<a class="anchor" id="section113"></a>
# - Use of Advanced ML Algorithms
#     - Bagging Algorithms
#     - Boosting Algorithms
#     - Stacking Algorithms
# - Improved creation of functions
# - Finer understanding of Python Code for ML Models.
# - Better understanding of EDA and its relevence.

# %% [markdown]
# ## 12. Acknowledgement<a class="anchor" id="section12"></a>
# - The project would not have been sucessful without the able guidance of instructors at INSAID and members of the Cohort. There contribution to evaluating and impoving the code has gone a long way in undertsnding the integrites of Machine Learning.
# - __Thank you for the wonderful opportunity__
